# %% [markdown]
# # Memory Agent (记忆智能体)
#
# ## 回顾
#
# 我们创建了一个聊天机器人，它将语义记忆保存到单个[用户档案](https://langchain-ai.github.io/langgraph/concepts/memory/#profile)或[集合](https://langchain-ai.github.io/langgraph/concepts/memory/#collection)中。
#
# 我们介绍了[Trustcall](https://github.com/hinthornw/trustcall)作为更新这两种架构的方法。
#
# ## 目标
#
# 现在，我们将把学到的各个部分结合起来，构建一个具有长期记忆的[智能体](https://langchain-ai.github.io/langgraph/concepts/agentic_concepts/)。
#
# 我们的智能体`task_mAIstro`将帮助我们管理待办事项列表！
#
# 我们之前构建的聊天机器人*总是*对对话进行反思并保存记忆。
#
# `task_mAIstro`将决定*何时*保存记忆（项目到我们的待办事项列表）。
#
# 我们之前构建的聊天机器人总是保存一种类型的记忆，档案或集合。
#
# `task_mAIstro`可以决定保存到用户档案或待办事项集合中的任何一个。
#
# 除了语义记忆外，`task_mAIstro`还将管理程序性记忆。
#
# 这允许用户更新他们创建待办事项的偏好。

# %%
# %%capture --no-stderr
# %pip install -U langchain_openai langgraph trustcall langchain_core
